# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('top50.csv',encoding='latin-1')
df.drop('Unnamed: 0',axis=1,inplace=True)
df.head()
# Out:
#                         Track.Name    Artist.Name           Genre  \
# 0                         Señorita   Shawn Mendes    canadian pop
# 1                            China       Anuel AA  reggaeton flow
# 2    boyfriend (with Social House)  Ariana Grande       dance pop
# 3  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
#    Length.  Acousticness..  Speechiness.  Popularity
# 0      191               4             3          79
# 1      302               8             9          92
# 2      186              12            46          85
# 3      198              12            19          86
# 4      175              45             7          94

# %% [markdown]
# 1.) Display details of the songs that have popularity above 80

# %%
df[df.Popularity>80].head()
# Out:
#                           Track.Name    Artist.Name           Genre  \
# 1                              China       Anuel AA  reggaeton flow
# 2      boyfriend (with Social House)  Ariana Grande       dance pop
# 3    Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4        Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
# 5  I Don't Care (with Justin Bieber)     Ed Sheeran             pop
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
# 5               102      68            80              -5         9        84
#
#    Length.  Acousticness..  Speechiness.  Popularity
# 1      302               8             9          92
# 2      186              12            46          85
# 3      198              12            19          86
# 4      175              45             7          94
# 5      220               9             4          84

# %% [markdown]
# 2.     Which is having maximum length, beats per minute?

# %%
df['Length.'].max()
# Out:
# 309

# %%
df['Beats.Per.Minute'].max()
# Out:
# 190

# %% [markdown]
# 3.      Which is having minimum length, beats per minute?

# %%
df['Length.'].min()
# Out:
# 115

# %%
df['Beats.Per.Minute'].min()
# Out:
# 85

# %% [markdown]
# 4.      Create new column to store string length

# %%
df['Track.Name.Length']=df['Track.Name'].apply(lambda s:len(s))
df.head()
# Out:
#                         Track.Name    Artist.Name           Genre  \
# 0                         Señorita   Shawn Mendes    canadian pop
# 1                            China       Anuel AA  reggaeton flow
# 2    boyfriend (with Social House)  Ariana Grande       dance pop
# 3  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
#    Length.  Acousticness..  Speechiness.  Popularity  Track.Name.Length
# 0      191               4             3          79                  8
# 1      302               8             9          92                  5
# 2      186              12            46          85                 29
# 3      198              12            19          86                 31
# 4      175              45             7          94                 27

# %% [markdown]
# `5.      Create new column to store first name of each artist

# %%
df['Artist.First.Name']=df['Artist.Name'].apply(lambda s:s.split(' ')[0])
df.head()
# Out:
#                         Track.Name    Artist.Name           Genre  \
# 0                         Señorita   Shawn Mendes    canadian pop
# 1                            China       Anuel AA  reggaeton flow
# 2    boyfriend (with Social House)  Ariana Grande       dance pop
# 3  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
#    Length.  Acousticness..  Speechiness.  Popularity  Track.Name.Length  \
# 0      191               4             3          79                  8
# 1      302               8             9          92                  5
# 2      186              12            46          85                 29
# 3      198              12            19          86                 31
# 4      175              45             7          94                 27
#
#   Artist.First.Name
# 0             Shawn
# 1             Anuel
# 2            Ariana
# 3                Ed
# 4              Post

# %% [markdown]
# 6.      How many songs from “dance pop” genre?

# %%
df[df.Genre=='dance pop'].shape[0]
# Out:
# 8

# %% [markdown]
# 7.      What is average length for each genre?

# %%
df.groupby('Genre')['Length.'].mean().reset_index().rename(columns={'Length.':'Average.Length'})
# Out:
#                Genre  Average.Length
# 0        atl hip hop      200.000000
# 1     australian pop      210.000000
# 2           big room      164.000000
# 3           boy band      181.000000
# 4            brostep      198.000000
# 5   canadian hip hop      193.000000
# 6       canadian pop      191.000000
# 7        country rap      136.000000
# 8          dance pop      202.625000
# 9            dfw rap      166.500000
# 10               edm      218.666667
# 11        electropop      194.500000
# 12       escape room      173.000000
# 13             latin      225.200000
# 14    panamanian pop      257.000000
# 15               pop      195.428571
# 16         pop house      153.000000
# 17    r&b en espanol      162.000000
# 18         reggaeton      213.500000
# 19    reggaeton flow      305.500000
# 20        trap music      131.000000

# %% [markdown]
# 8.      What is average length for each artist?

# %%
df.groupby('Artist.Name')['Length.'].mean().reset_index().rename(columns={'Length.':'Average.Length'})
# Out:
#          Artist.Name  Average.Length
# 0          Ali Gatie           213.0
# 1           Anuel AA           302.0
# 2      Ariana Grande           182.5
# 3          Bad Bunny           251.0
# 4      Billie Eilish           194.5
# 5        Chris Brown           261.0
# 6           DJ Snake           185.0
# 7       Daddy Yankee           193.0
# 8              Drake           205.0
# 9         Ed Sheeran           196.5
# 10          J Balvin           232.5
# 11       Jhay Cortez           309.0
# 12    Jonas Brothers           181.0
# 13        Katy Perry           224.0
# 14            Khalid           198.0
# 15              Kygo           228.0
# 16         Lady Gaga           216.0
# 17              Lauv           199.0
# 18     Lewis Capaldi           182.0
# 19         Lil Nas X           136.0
# 20         Lil Tecca           131.0
# 21             Lizzo           173.0
# 22             Lunay           266.0
# 23            MEDUZA           153.0
# 24            Maluma           176.0
# 25        Marshmello           198.0
# 26     Martin Garrix           164.0
# 27         Nicky Jam           202.0
# 28       Post Malone           166.5
# 29           ROSALÍA           162.0
# 30         Sam Smith           202.0
# 31              Sech           257.0
# 32      Shawn Mendes           191.0
# 33      Taylor Swift           171.0
# 34  The Chainsmokers           214.0
# 35       Tones and I           210.0
# 36               Y2K           161.0
# 37        Young Thug           200.0

# %% [markdown]
# 9.      What is maximum length for each genre?

# %%
df.groupby('Genre')['Length.'].max().reset_index().rename(columns={'Length.':'Max.Length'})
# Out:
#                Genre  Max.Length
# 0        atl hip hop         200
# 1     australian pop         210
# 2           big room         164
# 3           boy band         181
# 4            brostep         214
# 5   canadian hip hop         213
# 6       canadian pop         191
# 7        country rap         157
# 8          dance pop         261
# 9            dfw rap         175
# 10               edm         228
# 11        electropop         195
# 12       escape room         173
# 13             latin         266
# 14    panamanian pop         288
# 15               pop         220
# 16         pop house         153
# 17    r&b en espanol         162
# 18         reggaeton         251
# 19    reggaeton flow         309
# 20        trap music         131

# %% [markdown]
# 11.   How many songs share same popularity?

# %%
df.groupby('Popularity')['Track.Name'].count().reset_index().sort_values('Track.Name',ascending=False).reset_index().drop('index',axis=1)
# Out:
#     Popularity  Track.Name
# 0           88           8
# 1           89           8
# 2           91           7
# 3           87           4
# 4           90           3
# 5           84           3
# 6           92           3
# 7           82           2
# 8           83           2
# 9           86           2
# 10          94           1
# 11          93           1
# 12          70           1
# 13          78           1
# 14          85           1
# 15          80           1
# 16          79           1
# 17          95           1

# %% [markdown]
# 12.   Rank each song based on popularity.

# %%
df['Rank']=df.groupby('Popularity')['Track.Name'].transform(lambda x:x.rank())
df.loc[:,['Track.Name','Rank']].head(10)
# Out:
#                           Track.Name  Rank
# 0                           Señorita   1.0
# 1                              China   1.0
# 2      boyfriend (with Social House)   1.0
# 3    Beautiful People (feat. Khalid)   1.0
# 4        Goodbyes (Feat. Young Thug)   1.0
# 5  I Don't Care (with Justin Bieber)   1.0
# 6                             Ransom   3.0
# 7                  How Do You Sleep?   1.0
# 8              Old Town Road - Remix   2.0
# 9                            bad guy   1.0

# %% [markdown]
# 13.   Rank each song based on danceability.

# %%
df['Rank.Danceability']=df.groupby('Danceability')['Track.Name'].transform(lambda x:x.rank())
df.loc[:,['Track.Name','Rank.Danceability']].head(10)
# Out:
#                           Track.Name  Rank.Danceability
# 0                           Señorita                1.0
# 1                              China                1.0
# 2      boyfriend (with Social House)                1.0
# 3    Beautiful People (feat. Khalid)                1.0
# 4        Goodbyes (Feat. Young Thug)                1.0
# 5  I Don't Care (with Justin Bieber)                1.0
# 6                             Ransom                4.0
# 7                  How Do You Sleep?                1.0
# 8              Old Town Road - Remix                2.0
# 9                            bad guy                3.0

# %% [markdown]
# 14.   Average, Maximum, Minimum, standard deviation of each column

# %%
df.describe()
# Out:
#        Beats.Per.Minute     Energy  Danceability  Loudness..dB..   Liveness  \
# count         50.000000  50.000000      50.00000       50.000000  50.000000
# mean         120.060000  64.060000      71.38000       -5.660000  14.660000
# std           30.898392  14.231913      11.92988        2.056448  11.118306
# min           85.000000  32.000000      29.00000      -11.000000   5.000000
# 25%           96.000000  55.250000      67.00000       -6.750000   8.000000
# 50%          104.500000  66.500000      73.50000       -6.000000  11.000000
# 75%          137.500000  74.750000      79.75000       -4.000000  15.750000
# max          190.000000  88.000000      90.00000       -2.000000  58.000000
#
#         Valence.     Length.  Acousticness..  Speechiness.  Popularity  \
# count  50.000000   50.000000       50.000000     50.000000   50.000000
# mean   54.600000  200.960000       22.160000     12.480000   87.500000
# std    22.336024   39.143879       18.995553     11.161596    4.491489
# min    10.000000  115.000000        1.000000      3.000000   70.000000
# 25%    38.250000  176.750000        8.250000      5.000000   86.000000
# 50%    55.500000  198.000000       15.000000      7.000000   88.000000
# 75%    69.500000  217.500000       33.750000     15.000000   90.750000
# max    95.000000  309.000000       75.000000     46.000000   95.000000
#
#        Track.Name.Length       Rank  Rank.Danceability
# count          50.000000  50.000000          50.000000
# mean           19.160000   2.900000           1.540000
# std            14.637609   2.130919           0.734291
# min             4.000000   1.000000           1.000000
# 25%             8.000000   1.000000           1.000000
# 50%            15.000000   2.000000           1.000000
# 75%            26.500000   4.000000           2.000000
# max            68.000000   8.000000           4.000000

# %% [markdown]
# 15.   Average, Maximum, Minimum, standard deviation of each row

# %%
df.apply(lambda x: x.describe())
# Out:
#                            Track.Name Artist.Name      Genre  \
# 25%                               NaN         NaN        NaN
# 50%                               NaN         NaN        NaN
# 75%                               NaN         NaN        NaN
# count                              50          50         50
# freq                                1           4          8
# max                               NaN         NaN        NaN
# mean                              NaN         NaN        NaN
# min                               NaN         NaN        NaN
# std                               NaN         NaN        NaN
# top     boyfriend (with Social House)  Ed Sheeran  dance pop
# unique                             50          38         21
#
#         Beats.Per.Minute     Energy  Danceability  Loudness..dB..   Liveness  \
# 25%            96.000000  55.250000      67.00000       -6.750000   8.000000
# 50%           104.500000  66.500000      73.50000       -6.000000  11.000000
# 75%           137.500000  74.750000      79.75000       -4.000000  15.750000
# count          50.000000  50.000000      50.00000       50.000000  50.000000
# freq                 NaN        NaN           NaN             NaN        NaN
# max           190.000000  88.000000      90.00000       -2.000000  58.000000
# mean          120.060000  64.060000      71.38000       -5.660000  14.660000
# min            85.000000  32.000000      29.00000      -11.000000   5.000000
# std            30.898392  14.231913      11.92988        2.056448  11.118306
# top                  NaN        NaN           NaN             NaN        NaN
# unique               NaN        NaN           NaN             NaN        NaN
#
#          Valence.     Length.  Acousticness..  Speechiness.  Popularity  \
# 25%     38.250000  176.750000        8.250000      5.000000   86.000000
# 50%     55.500000  198.000000       15.000000      7.000000   88.000000
# 75%     69.500000  217.500000       33.750000     15.000000   90.750000
# count   50.000000   50.000000       50.000000     50.000000   50.000000
# freq          NaN         NaN             NaN           NaN         NaN
# max     95.000000  309.000000       75.000000     46.000000   95.000000
# mean    54.600000  200.960000       22.160000     12.480000   87.500000
# min     10.000000  115.000000        1.000000      3.000000   70.000000
# std     22.336024   39.143879       18.995553     11.161596    4.491489
# top           NaN         NaN             NaN           NaN         NaN
# unique        NaN         NaN             NaN           NaN         NaN
#
#         Track.Name.Length Artist.First.Name       Rank  Rank.Danceability
# 25%              8.000000               NaN   1.000000           1.000000
# 50%             15.000000               NaN   2.000000           1.000000
# 75%             26.500000               NaN   4.000000           2.000000
# count           50.000000                50  50.000000          50.000000
# freq                  NaN                 4        NaN                NaN
# max             68.000000               NaN   8.000000           4.000000
# mean            19.160000               NaN   2.900000           1.540000
# min              4.000000               NaN   1.000000           1.000000
# std             14.637609               NaN   2.130919           0.734291
# top                   NaN                Ed        NaN                NaN
# unique                NaN                37        NaN                NaN

# %% [markdown]
# 17.   Take log transform on Loudness DB and add as column

# %%
df['Loudness_log'] = np.log(np.abs(df['Loudness..dB..']))
df.head()
# Out:
#                         Track.Name    Artist.Name           Genre  \
# 0                         Señorita   Shawn Mendes    canadian pop
# 1                            China       Anuel AA  reggaeton flow
# 2    boyfriend (with Social House)  Ariana Grande       dance pop
# 3  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
#    Length.  Acousticness..  Speechiness.  Popularity  Track.Name.Length  \
# 0      191               4             3          79                  8
# 1      302               8             9          92                  5
# 2      186              12            46          85                 29
# 3      198              12            19          86                 31
# 4      175              45             7          94                 27
#
#   Artist.First.Name  Rank  Rank.Danceability  Loudness_log
# 0             Shawn   1.0                1.0      1.791759
# 1             Anuel   1.0                1.0      1.386294
# 2            Ariana   1.0                1.0      1.386294
# 3                Ed   1.0                1.0      2.079442
# 4              Post   1.0                1.0      1.386294

# %% [markdown]
# 18.   Visualize if there is linear correlation between beats per minutes and popularity, danceability and popularity, energy and popularity

# %%
df.columns
# Out:
# Index(['Track.Name', 'Artist.Name', 'Genre', 'Beats.Per.Minute', 'Energy',
#        'Danceability', 'Loudness..dB..', 'Liveness', 'Valence.', 'Length.',
#        'Acousticness..', 'Speechiness.', 'Popularity', 'Track.Name.Length',
#        'Artist.First.Name', 'Rank', 'Rank.Danceability', 'Loudness_log'],
#       dtype='object')

# %%
cols=['Beats.Per.Minute','Popularity','Danceability','Energy']
sns.heatmap(df[cols].corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# 19.   What is distribution of popularity with respect to energy

# %%
sns.countplot(df.groupby('Energy')['Popularity'].count()).set_title('Distribution')
plt.show()

# %% [markdown]
# 20.   What is distribution of popularity with respect to beats Per minute

# %%
sns.countplot(df.groupby('Beats.Per.Minute')['Popularity'].count()).set_title('Distribution')
plt.show()

# %% [markdown]
# 21.   Are there any outliers in popularity, danceability, beats per minute?

# %%
fig, ax = plt.subplots(1,3, figsize = (20,4))
sns.boxplot(df.Danceability, ax = ax[0], color = 'r')
sns.boxplot(df.Popularity, ax = ax[1], color = 'g')
sns.boxplot(df['Beats.Per.Minute'], ax = ax[2])
plt.show()

# %% [markdown]
# 22.   Visual each artist distribution

# %%
plt.figure(figsize = (25,4))
sns.countplot(df['Artist.Name'])
plt.xticks(rotation=70)
plt.show()

# %% [markdown]
# 23.   Visual each track name distribution

# %%
plt.figure(figsize = (25,6))
sns.countplot(df['Track.Name'])
plt.xticks(rotation=75)
plt.show()

# %% [markdown]
# 24.   Visual each genre distribution

# %%
plt.figure(figsize = (25,6))
sns.countplot(df['Genre'])
plt.xticks(rotation=75)
plt.show()

# %% [markdown]
# 25.   Visual artist, track, genre distribution using subplots

# %%
fig, ax = plt.subplots(3,1, figsize = (20,12) )
chart1 = sns.countplot(df['Genre'], ax = ax[0], color = 'b')
ax[0].set_xticklabels(chart1.get_xticklabels(), rotation=75)
chart2 = sns.countplot(df['Track.Name'], ax = ax[1], color = 'g')
ax[1].set_xticklabels(chart2.get_xticklabels(), rotation=45)
chart3 = sns.countplot(df['Artist.Name'], ax = ax[2], color = 'm')
ax[2].set_xticklabels(chart3.get_xticklabels(), rotation=75)
fig.tight_layout()
plt.show()
